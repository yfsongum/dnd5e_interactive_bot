# %%
import sys

# %%
#!{sys.executable} -m pip install langchain-openai langchain-community
#!{sys.executable} -m pip install langchain-qdrant
# Out:
# Collecting langchain-qdrant
#   Using cached langchain_qdrant-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-qdrant) (1.2.18)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain-qdrant) (2.12.5)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.15.1 in /opt/homebrew/lib/python3.11/site-packages (from langchain-qdrant) (1.17.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.25.0)
# Requirement already satisfied: anyio in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (4.12.0)
# Requirement already satisfied: certifi in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (1.0.9)
# Requirement already satisfied: idna in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant) (0.4.2)
# Requirement already satisfied: grpcio>=1.41.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (1.78.0)
# Requirement already satisfied: numpy>=1.21 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (2.4.3)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (7.34.0)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (2.6.0)
# Requirement already satisfied: h2<5,>=3 in /opt/homebrew/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.15.1->langchain-qdrant) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/chendonghao/Library/Python/3.11/lib/python/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.4.4)
# Using cached langchain_qdrant-1.1.0-py3-none-any.whl (24 kB)
# Installing collected packages: langchain-qdrant
# Successfully installed langchain-qdrant-1.1.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
#from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from langchain_core.documents import Document
from qdrant_client.models import Distance, VectorParams
from qdrant_client import QdrantClient
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv("si699.env")
# Out:
# True

# %% [markdown]
# ## Part 1 Chunking

# %%
damage_df = pd.read_json("dnd5eapi_dump/damage-types.json")
magic_schools_df = pd.read_json("dnd5eapi_dump/magic-schools.json")
alignments_df = pd.read_json("dnd5eapi_dump/alignments.json")
skills_df = pd.read_json("dnd5eapi_dump/skills.json")
languages_df = pd.read_json("dnd5eapi_dump/languages.json")
weapon_df = pd.read_json("dnd5eapi_dump/weapon-properties.json")
conditions_df = pd.read_json("dnd5eapi_dump/conditions.json")

# %%
def create_chunk(endpoint, url, items):
    desc = items.get("desc", "")
    if isinstance(desc, list):
        desc = " ".join(desc)
    ability = items.get("ability_score", {}).get("name", None)
    text = f"""
Type: {endpoint.replace('-', ' ').title()}
Name: {items.get("name")}
Associated Ability: {ability}

Category: {items.get("type", None)}
Script: {items.get("script", None)}
Typical Speakers: {", ".join(items.get("typical_speakers", []))}

Description:
{desc}
""".strip()

    chunk = {
        "id": f"{endpoint}_{items['index']}",
        "text": text,
        "metadata": {
            "endpoint": endpoint,
            "name": items.get("name"),
            "index": items.get("index"),
            "url": url + items.get("index"),
            "updated_at": items.get("updated_at"),
            "category": endpoint
        }
    }

    return chunk

# %%
def build_chunks(df):
    chunks = []
    for i in range(len(df)):
        endpoint, url, items = df.iloc[i, :]
        chunk = create_chunk(endpoint, url, items)
        chunks.append(chunk)
    return chunks

# %%
chunks = build_chunks(damage_df)
chunks.extend(build_chunks(magic_schools_df))
chunks.extend(build_chunks(alignments_df))
chunks.extend(build_chunks(skills_df))
chunks.extend(build_chunks(languages_df))
chunks.extend(build_chunks(weapon_df))
chunks.extend(build_chunks(conditions_df))

# %% [markdown]
# ## Part2: Embedding and Store Vectors

# %%
# model initialization
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
client = QdrantClient(path="./qdrant_local") # specify the path so that it persist locally on disk

docs = []
for chunk in chunks:
    docs.append(Document(
        page_content=chunk["text"],
        metadata = {
            **chunk["metadata"],
            "chunk_id": chunk["id"]
        }
    ))

# %%
collection_name = "damage_types"

client.create_collection(
    collection_name= collection_name,
    vectors_config= VectorParams(size=1536, #dimensinality of the vector
                                 distance=Distance.COSINE # distance metric for similarity search
    )
)

vectorstore = QdrantVectorStore(
    client=client,
    collection_name=collection_name,
    embedding=embedding_model
)

vectorstore.add_documents(docs)
# Out:
# ['6d761fe7c37a4918a55144092497edad',
#  'b1a542d8e9ef4135856bb30c7332feb8',
#  '75b89d7fdad34f90af857e8fa5ddb4cf',
#  '2a4f48d76b734ae2a254fc5b73ea6838',
#  '7a3094e36ffd40a39b3ab75ace986b16',
#  '0d131a31fcfd4315bbac5105661a38d8',
#  '6eba597a2de14e1baaaf0f99b4523c57',
#  '7354096886354119a95cc7ca31d3d5f5',
#  '0bb65e19daf94013ac26f1276a5c6b87',
#  '89b6b5470c73432290430c113f012556',
#  'b3a23e4c9dc5486a84ef578cb2dd590c',
#  '7556b37495c349cca7e668141fcf06c5',
#  '4508674a611b4b22b141605566ab0105',
#  '62ad3fa9bf4c447aa89f1e3be5cb3069',
#  '4bec77c3a0d24ac9a1e04335de5587ec',
#  '784af33379cd4da29ed5f3e9dde12079',
#  'b0031b4e729a45649db79dfb72ece5a3',
#  '5fe019c527714e3e89a8697f7a7b6716',
#  '0c5293135fed48c1a7f58af1fb746c19',
#  'ec352995fe3441629db43149c3ee64eb',
#  'd99683c3f46647d29a37dc8eb1da7b35',
#  '473e14ea4dc1422aaf618d0222b50529',
#  '32b046d7032041198cf39972d8d42586',
#  '8e6e609753ed42cfbdc3da159c256cc9',
#  'b1ac18898d874ac9bd1dc571be27fe03',
#  'cace924608fb4cf8aa8b072ad375f736',
#  '0a3dfd4424c646529f26a58df2bfe989',
#  '84178b40c37f43249d89f3d1ec2bc247',
#  '8a56b8e99fb74ca0a808becccc59025a',
#  'ec33e6a7cddf4cd8a8e2c6084d95d2c9',
#  '526399e1270e450db8d593b3c7cd28c9',
#  '3bc6f087d31b40e296d6d706fa0aa5af',
#  'c1b1ce1cbb4048f9a977821624faeb49',
#  'b852b0ea070e4176af3dd6cd611db4a5',
#  'a4686b640fdf498287729fa3123f2255',
#  'b0721effae52476b8df4c32c3fa38e57',
#  'bb17efd4429846c0ad0ee6365a33540b',
#  '325a7081884740f0a126773d45b57570',
#  '63a7664a510e4ae59086e6a8437644ef',
#  'e22bbca8cb9845059584790320ef05d3',
#  'd7afca0e162042da93cbcc2a7eae782b',
#  'db809580beff4dd6a75ca1f5707ca10e',
#  'e5120804c9cc4a179b390c1e8c9d1c3e',
#  'c03e5f0d82b44cc090bd05719032f7e7',
#  'c65f874d41a44eb2afc7e4712f44a261',
#  'b3a602defbe6499c82e1f3e1f797ffa7',
#  '1f01e057f23e44e9ba075f8f22d3de03',
#  'f8af1455350c4dc4b8704b503fb3edc2',
#  'bf5b035684f84b63ab6d653321e69a5e',
#  '2907ffe6ea344007ac2fac44fe8bd85a',
#  'bc33d65029834dcfa0f1b91ccd0b27ad',
#  'ce7d26e8e44b4ccca052d14ea75dceb2',
#  '6b2bd28cf40a45ae93471789a898b9d3',
#  '205e8be665d94db9a7dc911009e07eb6',
#  '30fd5e285433458e95cd2703064384ef',
#  '22a37168f5b145039a0fda9cb8f889bc',
#  'b590e1b8e26b4442a20cf256a2b725f6',
#  '191a0203af094fe69a8147d76837898a',
#  '14530f605a344524afd8840c6165ae73',
#  '0689d86cf5434623a9b07602da0616f6',
#  '0e4893ffa62247d1ba169055d8542af3',
#  '91feb30fb8164af19a8e3f04598d1c1d',
#  '0d21b7a71d7b4c77aa88ffcb591a5009',
#  '4d9aed2bc2f142408c58bb83e91f62f9',
#  'ebbc65a0f2524d1d80f24edc4c66c042',
#  '5f5e216ed5db46f1b03847bf008544e9',
#  'dfaf07a1010043f793e9050867145b0e',
#  '7c1c77df74b64245b66766688ba7c783',
#  '4feaecf8d4af4329a67b6613b4f333e3',
#  'e22d753359004bcd83a9b302a84cac48',
#  'e2d44c7ad29e4b579667ee117abad742',
#  'd2e53ef246e241cf8f4932f889506de7',
#  '66877e6d84d443d09509d7491a2daf05',
#  '536d6a0a0f6843718b80ef5bbecce6c7',
#  '6ace73256d8f4ec69517115dfda4e6d1',
#  '1cb7349067624d038b53814192fadeeb',
#  '44e88f52f9fe43a19b61ed9a702fc65e',
#  '992f66b6beb8401b842d1ad6ef8cf14a',
#  '97fec79375324b20a7a1713e9030ee71',
#  '213d6a99aade4e16acdcb735d9491fcb',
#  '39f609e7186142e79bbc5429c95494fe',
#  '054096ce31374263932e55b1af10360b',
#  '8acaa17403f54b35a73c2df645186e01',
#  '5861aa292446484d88c7ce1607f7904e',
#  '8d98ed01b61542d9ba357ae6fbb9cff5',
#  '4f0d2d78be3d4e22a7ca3cdb7a9ad8a9',
#  '01a2f0660f3545da90efeb72f417bbf6',
#  'dbacddf380de4e65b6849710a549dc1d',
#  '90de7abf5906455c9f9857f41847663c',
#  'e53cb65aa59c4fac8e55e95043be2c68']

# %% [markdown]
# ## Part 3: Retrival

# %%
def retrieve_chunks(vectorstore, query, k=3):
    results = vectorstore.similarity_search(query, k=k)
    return results

# %%
def build_context(retrieved_docs):
    contexts = []
    for i, doc in enumerate(retrieved_docs, 1):
        contexts.append(f"[Chunk {i} | {doc.metadata.get('chunk_id')} | {doc.metadata.get('name')}]\n{doc.page_content}")
        
    return "\n\n".join(contexts)

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
rag_prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
You are a helpful Dungeons & Dragons rules assistant.

Use only the retrieved context below to answer the question.
If the answer is not contained in the context, say "I don't know based on the retrieved context."

Retrieved Context:
{context}

Question:
{question}

Answer:
""".strip()
)

# %%
def rag_pipeline(query, llm, vectorstore, prompt_template, k=3):
    retrived_docs = retrieve_chunks(vectorstore, query, k)
    print(len(retrived_docs))
    context = build_context(retrived_docs)
    prompt = prompt_template.format(context=context, question=query)
    answer = llm.invoke(prompt).content
    
    return retrived_docs, context, answer

# %%
query = "If i want to fight with two weapons, what kind of weapon should i use?"

retrieved_docs, context, answer = rag_pipeline(
    query=query,
    vectorstore=vectorstore,
    llm=llm,
    prompt_template=rag_prompt,
    k=3
)

print(context)
print()
print(answer)
# Out:
# 3
# [Chunk 1 | weapon-properties_two-handed | Two-Handed]
# Type: Weapon Properties
# Name: Two-Handed
# Associated Ability: None
#
# Category: None
# Script: None
# Typical Speakers:
#
# Description:
# This weapon requires two hands when you attack with it.
#
# [Chunk 2 | weapon-properties_versatile | Versatile]
# Type: Weapon Properties
# Name: Versatile
# Associated Ability: None
#
# Category: None
# Script: None
# Typical Speakers:
#
# Description:
# This weapon can be used with one or two hands. A damage value in parentheses appears with the property--the damage when the weapon is used with two hands to make a melee attack.
#
# [Chunk 3 | weapon-properties_light | Light]
# Type: Weapon Properties
# Name: Light
# Associated Ability: None
#
# Category: None
# Script: None
# Typical Speakers:
#
# Description:
# A light weapon is small and easy to handle, making it ideal for use when fighting with two weapons.
#
# You should use light weapons, as they are small and easy to handle, making them ideal for fighting with two weapons.
